# %% [markdown]
# # Pandas Data Visualization Exercise
#
# - This is just a quick exercise for you to review the various plots we showed earlier.
# - Use **df3** to replicate the following plots.

# %%
print ("This is done by John Callahan")
import pandas as pd
import matplotlib.pyplot as plt
df3 = pd.read_csv('data/df3')
# %matplotlib inline
# Out:
# This is done by John Callahan

# %%
print ("This is done by John Callahan")
df3.info()
# Out:
# This is done by John Callahan
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       500 non-null    float64
#  1   b       500 non-null    float64
#  2   c       500 non-null    float64
#  3   d       500 non-null    float64
# dtypes: float64(4)
# memory usage: 15.8 KB

# %%
print ("This is done by John Callahan")
df3.head()
# Out:
# This is done by John Callahan
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %% [markdown]
# - Recreate this scatter plot of b vs a.
# - Note the color and size of the points.
# - Also note the figure size.
# - See if you can figure out how to stretch it in a similar fashion. Remeber back to your matplotlib lecture

# %%
print ("This is done by John Callahan")
df3.plot.scatter(x='a',y='b',figsize=(8,3),c='Red')
# Out:
# This is done by John Callahan
# <Axes: xlabel='a', ylabel='b'>

# %% [markdown]
# - Create a histogram of the 'a' column.

# %%
print ("This is done by John Callahan")
df3['a'].plot.hist()
# Out:
# This is done by John Callahan
# <Axes: ylabel='Frequency'>

# %% [markdown]
# - These plots are okay, but they don't look very polished.
# - Use style sheets to set the style to 'ggplot' and redo the histogram from above.
# - Also figure out how to add more bins to it.

# %%
print ("This is done by John Callahan")
df3['a'].plot.hist()
plt.style.use('ggplot')
# Out:
# This is done by John Callahan

# %%
print ("This is done by John Callahan")
df3['a'].plot.hist(bins=75)
# Out:
# This is done by John Callahan
# <Axes: ylabel='Frequency'>

# %% [markdown]
# - Create a boxplot comparing the a and b columns.

# %%
print ("This is done by John Callahan")
df3.plot.box(column=['a','b'])
# Out:
# This is done by John Callahan
# <Axes: >

# %% [markdown]
# - Create an area plot of all the columns for just the rows up to 30. (hint: use .ix).

# %%
print ("This is done by John Callahan")
df3[0:31].plot.area(stacked=True,alpha=0.5)
# Out:
# This is done by John Callahan
# <Axes: >
