# %% [markdown]
# **Seaborn Exercises (Worth 70 points)**
# Time to practice your new seaborn skills! Try to recreate the plots below

# %% [markdown]
# ## The Data
#
# We will be working with a famous titanic data set for these exercises. For now, we'll just focus on the visualization of the data with seaborn:

# %%
print ("This is done by John Callahan")
import warnings
warnings.filterwarnings('ignore')

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# This is done by John Callahan

# %%
print ("This is done by John Callahan")
sns.set_style('whitegrid')
# Out:
# This is done by John Callahan

# %%
print ("This is done by John Callahan")
titanic = sns.load_dataset('titanic')
# Out:
# This is done by John Callahan

# %%
print ("This is done by John Callahan")
titanic.head()
# Out:
# This is done by John Callahan
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# **Exercise 1 (worth 10 points)**
#
# ** Recreate the plots below using the titanic dataframe. There are very few hints since most of the plots can be done with just one or two lines of code and a hint would basically give away the solution. Keep careful attention to the x and y labels for hints.**
#
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
print ("This is done by John Callahan")
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!
sns.jointplot(x='fare',y='age',data=titanic)
# Out:
# This is done by John Callahan

# %% [markdown]
# **Exercise 2 (Worth 10 points)**

# %%
print ("This is done by John Callahan")
#I could not figure out the color used
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!
sns.distplot(titanic['fare'],kde=False,color='Salmon')
# Out:
# This is done by John Callahan
# <Axes: xlabel='fare'>

# %% [markdown]
# **Exercise 3 (Worth 10 points)**

# %%
print ("This is done by John Callahan")
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!
sns.boxplot(x='class',y='age',data=titanic,palette='rainbow')
# Out:
# This is done by John Callahan
# <Axes: xlabel='class', ylabel='age'>

# %% [markdown]
# **Exercise 4 (Worth 10 points)**

# %%
print ("This is done by John Callahan")
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!
sns.swarmplot(x='class',y='age',data=titanic,palette='Set2')
# Out:
# This is done by John Callahan
# <Axes: xlabel='class', ylabel='age'>

# %% [markdown]
# **Exercise 5 (Worth 10 points)**

# %%
print ("This is done by John Callahan")
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!
sns.set_style('white')
sns.countplot(x='sex',data=titanic)
# Out:
# This is done by John Callahan
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# **Exercise 6 (Worth 10 points)**

# %%
print ("This is done by John Callahan")
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!
sns.heatmap(titanic.corr(numeric_only=True),cmap='coolwarm')
# Out:
# This is done by John Callahan
# <Axes: >

# %%
# Out:
# Text(0.5,1,'titanic.corr()')

# %% [markdown]
# **Exercise 7 (Worth 10 points)**

# %%
print ("This is done by John Callahan")
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!
sns.set_style('ticks')
g=sns.FacetGrid(data=titanic,col='sex')
g.map(plt.hist,'age')
# Out:
# This is done by John Callahan
